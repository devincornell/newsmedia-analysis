# %%
import networkx as nx
import gensim.models
from os import walk
import numpy as np
import pandas as pd
import pickle
import sys
import re
import semanticanalysis as sa
import functools
import itertools
from multiprocessing import Pool
import sys
import pickle

# %%
def getfilenames(folder, model_extension):
    # get model filenames
    files = dict()
    modelfiles, wordfreqfiles = list(), list()
    for (dirpath, dirnames, filenames) in walk(folder):
        for file in filenames:
            if file[-len(model_extension):] == model_extension:
                srcname = file.split('.')[0]
                files[srcname] = folder + file
    return files
fnames = getfilenames('results/mat_common/', '.hdf')

# %%
L = 8
probs = [0.8,0.999]
words = ['trump', 'military']

for p in probs:
    for word in words:

        print('p =', p, 'word =', word)
        print()
        print('\\begin{tabular}{ l |', ' '.join(['c',]*(L+1)), '}')
        print('\hline')
        for src, fname in fnames.items():
            S = pd.read_hdf(fname, key='S')

            srcname = src.split('_')[0]
            
            topic = sa.centralized_randomwalk(word, matrix=S, returnprob=p, max_iter=1000, verbose=False)
            scores = np.array([t[1] for t in topic[1:]])
            u = np.mean(scores)
            std = np.std(scores)
            nscores = (scores - u)/std
            
            print('\\textbf{'+srcname+'} &', ' & '.join([w for w,s in topic[1:L+1]]), '\\\\')
            print('{0:.3e} &'.format(u), ' & '.join(['{0:.4f}'.format(s) for s in nscores[1:L+1]]), '\\\\')
            print('\hline')

        print('\end{tabular}')
        print()
        print()
# Out:
# p = 0.8 word = trump
#
# \begin{tabular}{ l | c c c c c c c c c }
# \hline
# \textbf{wapo} & boycott & donald & signals & swamp & drain & conway & earliest & sharp \\
# 4.075e-05 & 2.5148 & 2.4395 & 2.3987 & 2.3686 & 2.2973 & 2.2827 & 2.2782 & 2.2769 \\
# \hline
# \textbf{usatoday} & donald & president & obama & campaign & presidential & administration & clinton & election \\
# 4.077e-05 & 7.8890 & 7.8145 & 7.6074 & 7.3224 & 6.6768 & 6.6371 & 6.5446 & 6.2279 \\
# \hline
# \textbf{nytimes} & echoed & expressed & stunning & donald & pledge & kellyanne & strongly & outcome \\
# 4.075e-05 & 2.4933 & 2.4487 & 2.4184 & 2.3954 & 2.3640 & 2.3459 & 2.3431 & 2.3180 \\
# \hline
# \textbf{breitbart} & trumps & inauguration & victory & cabinet & candidate & campaign & vote & elected \\
# 4.077e-05 & 2.5721 & 2.5406 & 2.3889 & 2.3638 & 2.3500 & 2.3493 & 2.3455 & 2.3097 \\
# \hline
# \textbf{cbsnews} & trumps & presidential & clinton & election & hillary & campaign & obama & president \\
# 4.077e-05 & 6.6431 & 6.4485 & 6.3030 & 6.1266 & 6.1246 & 5.9904 & 5.8386 & 5.7531 \\
# \hline
# \textbf{cnn} & attending & sign & clear & trail & issue & transition & vowed & brexit \\
# 4.076e-05 & 2.0801 & 2.0571 & 1.9429 & 1.9250 & 1.9177 & 1.9068 & 1.9040 & 1.8685 \\
# \hline
# \textbf{foxnews} & candidate & hillary & win & presidency & cabinet & elected & putin & presidential \\
# 4.077e-05 & 2.2119 & 2.1917 & 2.1659 & 2.1043 & 2.0940 & 2.0864 & 2.0408 & 2.0245 \\
# \hline
# \textbf{watimes} & trumps & swamp & incoming & donald & billionaire & drain & cabinet & perhaps \\
# 4.076e-05 & 2.3451 & 2.2691 & 2.2515 & 2.2491 & 2.2411 & 2.2159 & 2.2053 & 2.1570 \\
# \hline
# \textbf{reuters} & donald & swamp & tone & stunning & drain & possibilities & style & trumps \\
# 4.074e-05 & 2.8041 & 2.7776 & 2.6924 & 2.6674 & 2.6380 & 2.6303 & 2.5858 & 2.5449 \\
# \hline
# \textbf{huffpo} & swamp & drain & donald & campaigned & picks & cabinet & analysts & inaugurated \\
# 4.075e-05 & 3.3179 & 2.9983 & 2.6926 & 2.6617 & 2.5858 & 2.5794 & 2.5766 & 2.5696 \\
# \hline
# \end{tabular}
#
#
# p = 0.8 word = military
#
# \begin{tabular}{ l | c c c c c c c c c }
# \hline
# \textbf{wapo} & civilian & missions & command & combat & counterterrorism & cyber & personnel & operations \\
# 4.075e-05 & 3.1365 & 3.0444 & 3.0142 & 2.9587 & 2.9474 & 2.9036 & 2.8006 & 2.7186 \\
# \hline
# \textbf{usatoday} & regulators & requires & concluded & procedures & website & addition & restrictions & allowing \\
# 4.078e-05 & 0.2355 & 0.2349 & 0.2331 & 0.2323 & 0.2312 & 0.2306 & 0.2294 & 0.2293 \\
# \hline
# \textbf{nytimes} & civilian & missile & counterterrorism & strikes & units & iranian & airstrikes & allied \\
# 4.076e-05 & 2.4761 & 2.4571 & 2.4198 & 2.3938 & 2.3580 & 2.3412 & 2.2912 & 2.2813 \\
# \hline
# \textbf{breitbart} & sea & vietnam & forces & islands & troops & chinese & sudan & korea \\
# 4.077e-05 & 1.9720 & 1.9240 & 1.9231 & 1.9210 & 1.8961 & 1.8898 & 1.7937 & 1.7921 \\
# \hline
# \textbf{cbsnews} & rebels & iran & coalition & central & turkey & aid & iraqi & alongside \\
# 4.078e-05 & 0.4206 & 0.3884 & 0.3638 & 0.3578 & 0.3570 & 0.3562 & 0.3522 & 0.3521 \\
# \hline
# \textbf{cnn} & aircraft & pacific & air & assad & troops & retake & japan & missile \\
# 4.077e-05 & 2.3693 & 2.2763 & 2.2319 & 2.1742 & 2.1447 & 2.1402 & 2.1286 & 2.1203 \\
# \hline
# \textbf{foxnews} & turkey & opposition & israeli & kurdish & al & radical & backed & libya \\
# 4.077e-05 & 2.1637 & 2.1046 & 2.0621 & 2.0472 & 2.0215 & 2.0199 & 2.0115 & 1.9978 \\
# \hline
# \textbf{watimes} & civilian & forces & deployed & force & combat & operating & ground & factions \\
# 4.076e-05 & 2.3199 & 2.3028 & 2.2451 & 2.1597 & 2.1031 & 2.0732 & 2.0694 & 2.0451 \\
# \hline
# \textbf{reuters} & missions & pilots & ground & carriers & conducting & airstrikes & troops & mounted \\
# 4.074e-05 & 2.8332 & 2.7597 & 2.7289 & 2.7203 & 2.7125 & 2.7047 & 2.6548 & 2.6381 \\
# \hline
# \textbf{huffpo} & command & operations & sought & units & rebels & troops & peninsula & withdrawal \\
# 4.076e-05 & 2.7990 & 2.6680 & 2.5997 & 2.5966 & 2.5661 & 2.5371 & 2.5208 & 2.5110 \\
# \hline
# \end{tabular}
#
#
# p = 0.999 word = trump
#
# \begin{tabular}{ l | c c c c c c c c c }
# \hline
# \textbf{wapo} & donald & boycott & swamp & drain & conway & signals & suggested & enrique \\
# 2.037e-07 & 2.6774 & 2.6365 & 2.5751 & 2.5675 & 2.5145 & 2.4073 & 2.4029 & 2.3862 \\
# \hline
# \textbf{usatoday} & donald & president & obama & campaign & presidential & election & administration & clinton \\
# 2.039e-07 & 10.4482 & 9.2013 & 8.4359 & 8.1513 & 7.6233 & 7.4759 & 7.3171 & 6.7183 \\
# \hline
# \textbf{nytimes} & donald & expressed & echoed & outcome & stunning & kellyanne & cabinet & pledge \\
# 2.037e-07 & 2.6933 & 2.6397 & 2.6031 & 2.5622 & 2.5308 & 2.5178 & 2.4975 & 2.4858 \\
# \hline
# \textbf{breitbart} & trumps & victory & election & inauguration & campaign & incoming & vote & candidate \\
# 2.038e-07 & 3.0316 & 2.9852 & 2.9773 & 2.8874 & 2.7824 & 2.7597 & 2.7493 & 2.7429 \\
# \hline
# \textbf{cbsnews} & trumps & presidential & election & clinton & president & obama & campaign & donald \\
# 2.038e-07 & 7.5997 & 7.3749 & 7.3417 & 7.1659 & 7.0921 & 7.0355 & 6.9398 & 6.8167 \\
# \hline
# \textbf{cnn} & attending & clear & transition & realdonaldtrump & sign & trail & candidate & vowed \\
# 2.038e-07 & 2.2960 & 2.2830 & 2.2805 & 2.2758 & 2.2705 & 2.2118 & 2.1578 & 2.1351 \\
# \hline
# \textbf{foxnews} & hillary & candidate & win & presidential & putin & presidency & election & incoming \\
# 2.038e-07 & 2.6437 & 2.5418 & 2.5408 & 2.5268 & 2.4378 & 2.4329 & 2.4265 & 2.3843 \\
# \hline
# \textbf{watimes} & trumps & donald & incoming & cabinet & swamp & pence & billionaire & drain \\
# 2.037e-07 & 2.6318 & 2.5673 & 2.4894 & 2.4509 & 2.4031 & 2.3804 & 2.3364 & 2.3264 \\
# \hline
# \textbf{reuters} & donald & tone & swamp & stunning & trumps & promise & drain & priorities \\
# 2.037e-07 & 2.9042 & 2.8665 & 2.7934 & 2.7434 & 2.7076 & 2.6831 & 2.6620 & 2.6167 \\
# \hline
# \textbf{huffpo} & swamp & drain & donald & cabinet & picks & campaigned & inaugurated & analysts \\
# 2.037e-07 & 3.4446 & 3.4177 & 2.8733 & 2.8245 & 2.7655 & 2.6636 & 2.6592 & 2.6351 \\
# \hline
# \end{tabular}
#
#
# p = 0.999 word = military
#
# \begin{tabular}{ l | c c c c c c c c c }
# \hline
# \textbf{wapo} & civilian & command & missions & counterterrorism & combat & personnel & cyber & operations \\
# 2.037e-07 & 3.3635 & 3.3117 & 3.2215 & 3.2212 & 3.1638 & 3.1355 & 3.1288 & 3.0111 \\
# \hline
# \textbf{usatoday} & regulators & requires & allows & agents & website & concluded & addition & procedures \\
# 2.039e-07 & 0.2735 & 0.2677 & 0.2634 & 0.2621 & 0.2614 & 0.2590 & 0.2586 & 0.2577 \\
# \hline
# \textbf{nytimes} & counterterrorism & civilian & units & missile & airstrikes & iranian & strikes & weapons \\
# 2.038e-07 & 2.6042 & 2.6025 & 2.5813 & 2.5576 & 2.5256 & 2.4849 & 2.4406 & 2.4271 \\
# \hline
# \textbf{breitbart} & sea & forces & south & troops & sudan & vietnam & chinese & islands \\
# 2.038e-07 & 2.5680 & 2.4472 & 2.3564 & 2.3316 & 2.2833 & 2.2737 & 2.2272 & 2.2004 \\
# \hline
# \textbf{cbsnews} & rebels & iran & iraqi & civil & militants & coalition & troops & fighting \\
# 2.039e-07 & 0.4880 & 0.4799 & 0.4514 & 0.4416 & 0.4373 & 0.4257 & 0.4225 & 0.4191 \\
# \hline
# \textbf{cnn} & aircraft & assad & pacific & air & troops & japan & ukraine & regime \\
# 2.038e-07 & 2.7186 & 2.7086 & 2.6490 & 2.6238 & 2.4554 & 2.4287 & 2.4252 & 2.4125 \\
# \hline
# \textbf{foxnews} & turkey & opposition & israeli & kurdish & al & coalition & assad & libya \\
# 2.038e-07 & 2.5715 & 2.4752 & 2.4494 & 2.4374 & 2.4040 & 2.3645 & 2.3643 & 2.3363 \\
# \hline
# \textbf{watimes} & civilian & forces & force & deployed & turkish & troops & command & known \\
# 2.038e-07 & 2.8829 & 2.7076 & 2.5263 & 2.4806 & 2.3639 & 2.3369 & 2.3150 & 2.3124 \\
# \hline
# \textbf{reuters} & ground & troops & pilots & missions & aircraft & commander & conducting & airstrikes \\
# 2.037e-07 & 3.0746 & 2.9431 & 2.8750 & 2.8627 & 2.8365 & 2.8070 & 2.7934 & 2.7674 \\
# \hline
# \textbf{huffpo} & operations & command & troops & rebels & sought & units & sudan & korean \\
# 2.037e-07 & 2.9800 & 2.8771 & 2.8079 & 2.7842 & 2.6610 & 2.6487 & 2.6259 & 2.6213 \\
# \hline
# \end{tabular}

# %%
import networkx as nx
import gensim.models
from os import walk
import numpy as np
import pandas as pd
import pickle
import sys
import re
import semanticanalysis as sa
import functools
import itertools
from multiprocessing import Pool
import sys
import pickle

# %%
def getfilenames(folder, model_extension):
    # get model filenames
    files = dict()
    modelfiles, wordfreqfiles = list(), list()
    for (dirpath, dirnames, filenames) in walk(folder):
        for file in filenames:
            if file[-len(model_extension):] == model_extension:
                srcname = file.split('.')[0]
                files[srcname] = folder + file
    return files
fnames = getfilenames('results/mat_medium25/', '.hdf')

# %%
l = 10
probs = [0.1, 0.5, 0.9, 0.99]
words = ['trump', 'military', 'clinton', 'war']

for word in words:
    for p in probs:
        print('"{}" ==========================='.format(word))
        print('p = {} ============'.format(p))
        for src, fname in fnames.items():
            S = pd.read_hdf(fname, key='S')
            
            print(src)
            topic = sa.centralized_randomwalk(word, matrix=S, returnprob=p, max_iter=1000, verbose=True)
            scores = np.array([t[1] for t in topic[1:]])
            u = np.mean(scores)
            std = np.std(scores)
            nscores = (scores - u)/std

            for w,s in topic[1:l]:
                print('{}'.format(w),end=', ')
            print()
            for s in nscores[1:l]:
                print('{0:.3f}'.format(s),end=', ')
            print()
            print()
# Out:
# "trump" ===========================
# p = 0.1 ============
# wapo_pars
# performed 37 iterations.
# heated, shifting, attempting, accepting, highlights, explaining, breaking, normally, mere,
# 1.944, 1.941, 1.939, 1.934, 1.896, 1.876, 1.864, 1.859, 1.854,
#
# foxnews_pars
# performed 40 iterations.
# library, hollande, clearly, successful, break, attempt, works, numerous, unclear,
# 1.057, 1.050, 1.039, 1.038, 1.030, 1.024, 1.019, 1.019, 1.013,
#
# cbsnews_pars
# performed 20 iterations.
# toward, inauguration, serve, build, questions, message, became, policies, choice,
# 0.545, 0.545, 0.544, 0.535, 0.535, 0.535, 0.534, 0.533, 0.533,
#
# cnn_pars
# performed 41 iterations.
# fully, figures, discussion, points, fair, rare, appears, amid, subject,
# 1.299, 1.292, 1.282, 1.272, 1.268, 1.267, 1.261, 1.252, 1.247,
#
# nytimes_pars
# performed 45 iterations.
# map, discussions, participate, participants, demonstrated, chaotic, notable, blow, troubles,
# 1.778, 1.767, 1.757, 1.743, 1.742, 1.721, 1.720, 1.718, 1.708,
#
# usatoday_pars
# performed 37 iterations.
# team, pence, nominees, transition, candidate, democrats, final, far, anyone,
# 0.492, 0.489, 0.487, 0.484, 0.483, 0.481, 0.479, 0.478, 0.477,
#
# breitbart_pars
# performed 39 iterations.
# third, damage, argued, progressive, intended, discuss, thus, comment, started,
# 1.087, 1.084, 1.080, 1.077, 1.075, 1.073, 1.068, 1.065, 1.064,
#
# reuters_pars
# performed 1001 iterations.
# pointing, favors, warnings, indeed, breaking, acted, underway, latter, traditionally,
# 2.548, 2.416, 2.416, 2.407, 2.331, 2.318, 2.291, 2.266, 2.252,
#
# huffpo_pars
# performed 47 iterations.
# emphasized, attempting, suit, ignoring, nonetheless, begun, involves, founders, developments,
# 2.099, 2.065, 2.065, 2.039, 2.037, 2.018, 2.004, 2.002, 1.996,
#
# watimes_pars
# performed 45 iterations.
# regularly, intent, actual, gain, highly, troubling, appear, laid, reputation,
# 1.780, 1.766, 1.755, 1.750, 1.749, 1.747, 1.738, 1.733, 1.731,
#
# "trump" ===========================
# p = 0.5 ============
# wapo_pars
# performed 27 iterations.
# signaled, worries, sharp, campaigned, notion, fairly, boycott, privately, donald,
# 2.001, 1.998, 1.998, 1.993, 1.981, 1.979, 1.945, 1.926, 1.925,
#
# foxnews_pars
# performed 21 iterations.
# candidate, nominees, hearings, conversation, elections, suggested, winning, cabinet, elected,
# 1.444, 1.429, 1.416, 1.411, 1.410, 1.406, 1.389, 1.387, 1.368,
#
# cbsnews_pars
# performed 17 iterations.
# hillary, presidential, candidate, trumps, clinton, republican, transition, campaign, obama,
# 2.232, 2.185, 2.176, 2.103, 2.082, 2.034, 2.022, 2.010, 1.947,
#
# cnn_pars
# performed 1001 iterations.
# clear, issue, jared, accept, expected, appeal, attending, effort, transition,
# 1.650, 1.542, 1.539, 1.531, 1.510, 1.504, 1.504, 1.491, 1.486,
#
# nytimes_pars
# performed 1001 iterations.
# donald, pledge, consistent, warning, discussions, considering, specifically, strongly, controversial,
# 2.039, 2.031, 2.015, 1.993, 1.974, 1.954, 1.907, 1.867, 1.832,
#
# usatoday_pars
# performed 1001 iterations.
# campaign, obama, presidential, election, clinton, administration, presidency, inauguration, hillary,
# 3.312, 3.156, 3.059, 3.025, 2.880, 2.568, 2.533, 2.347, 2.302,
#
# breitbart_pars
# performed 19 iterations.
# trumps, inauguration, gop, hope, comes, candidate, reagan, vice, pence,
# 1.614, 1.559, 1.556, 1.551, 1.550, 1.534, 1.524, 1.522, 1.472,
#
# reuters_pars
# performed 23 iterations.
# donald, priorities, trumps, tone, promise, inaugurated, choices, reaction, pledges,
# 2.779, 2.716, 2.644, 2.636, 2.559, 2.508, 2.489, 2.488, 2.467,
#
# huffpo_pars
# performed 21 iterations.
# swamp, drawn, donald, analysts, apparent, kremlin, promises, attacking, nonetheless,
# 2.505, 2.364, 2.281, 2.169, 2.161, 2.146, 2.143, 2.120, 2.117,
#
# watimes_pars
# performed 22 iterations.
# trumps, warning, billionaire, incoming, donald, upset, surprise, widely, rarely,
# 2.074, 2.042, 1.940, 1.926, 1.914, 1.894, 1.888, 1.886, 1.886,
#
# "trump" ===========================
# p = 0.9 ============
# wapo_pars
# performed 13 iterations.
# donald, signaled, trail, swamp, drain, repeatedly, promised, campaigned, conway,
# 2.332, 2.320, 2.302, 2.192, 2.179, 2.177, 2.143, 2.134, 2.101,
#
# foxnews_pars
# performed 11 iterations.
# presidential, hillary, election, clinton, cabinet, putin, candidate, confirmation, incoming,
# 2.077, 1.999, 1.980, 1.886, 1.874, 1.871, 1.865, 1.858, 1.818,
#
# cbsnews_pars
# performed 10 iterations.
# trumps, obama, presidential, clinton, hillary, campaign, election, president, administration,
# 3.822, 3.602, 3.599, 3.503, 3.415, 3.270, 3.216, 3.096, 2.984,
#
# cnn_pars
# performed 12 iterations.
# transition, clear, issue, candidate, trail, question, attending, realdonaldtrump, orders,
# 2.102, 1.986, 1.903, 1.838, 1.815, 1.768, 1.767, 1.761, 1.740,
#
# nytimes_pars
# performed 13 iterations.
# donald, washington, transition, nieto, cabinet, expressed, pea, presidency, strongly,
# 2.503, 2.418, 2.367, 2.348, 2.313, 2.312, 2.295, 2.262, 2.255,
#
# usatoday_pars
# performed 10 iterations.
# donald, president, campaign, obama, election, presidential, clinton, administration, presidency,
# 5.365, 4.948, 4.754, 4.719, 3.966, 3.824, 3.817, 2.939, 2.915,
#
# breitbart_pars
# performed 11 iterations.
# trumps, election, inauguration, candidate, presidential, republican, vote, campaign, elected,
# 2.398, 2.135, 2.099, 2.096, 1.992, 1.984, 1.941, 1.937, 1.936,
#
# reuters_pars
# performed 13 iterations.
# donald, promise, trumps, trail, incoming, republican, priorities, tone, inaugurated,
# 3.313, 3.205, 2.997, 2.881, 2.871, 2.867, 2.841, 2.784, 2.691,
#
# huffpo_pars
# performed 12 iterations.
# donald, swamp, cabinet, promises, presidency, drawn, rhetoric, russians, elect,
# 3.163, 2.689, 2.667, 2.610, 2.524, 2.487, 2.483, 2.452, 2.431,
#
# watimes_pars
# performed 12 iterations.
# trumps, donald, incoming, comments, cabinet, presidents, billionaire, presidential, tsai,
# 2.987, 2.625, 2.324, 2.304, 2.268, 2.204, 2.193, 2.137, 2.119,
#
# "trump" ===========================
# p = 0.99 ============
# wapo_pars
# performed 8 iterations.
# donald, trail, swamp, signaled, drain, promised, conway, repeatedly, transition,
# 2.400, 2.373, 2.362, 2.245, 2.245, 2.233, 2.231, 2.176, 2.158,
#
# foxnews_pars
# performed 8 iterations.
# presidential, hillary, election, clinton, putin, incoming, cabinet, confirmation, candidate,
# 2.187, 2.116, 2.102, 1.966, 1.953, 1.942, 1.934, 1.911, 1.897,
#
# cbsnews_pars
# performed 7 iterations.
# trumps, obama, clinton, presidential, hillary, campaign, president, election, donald,
# 4.033, 3.770, 3.756, 3.637, 3.574, 3.504, 3.463, 3.321, 3.237,
#
# cnn_pars
# performed 8 iterations.
# transition, clear, issue, candidate, trail, question, realdonaldtrump, orders, inauguration,
# 2.151, 2.024, 1.990, 1.907, 1.861, 1.850, 1.832, 1.804, 1.798,
#
# nytimes_pars
# performed 8 iterations.
# donald, washington, transition, cabinet, nieto, presidency, pea, expressed, team,
# 2.661, 2.510, 2.453, 2.447, 2.398, 2.388, 2.370, 2.339, 2.319,
#
# usatoday_pars
# performed 6 iterations.
# donald, president, campaign, obama, election, presidential, administration, clinton, presidency,
# 5.791, 5.068, 4.886, 4.877, 4.028, 3.895, 3.886, 2.957, 2.934,
#
# breitbart_pars
# performed 7 iterations.
# trumps, election, presidential, inauguration, candidate, republican, vote, incoming, campaign,
# 2.552, 2.225, 2.196, 2.164, 2.100, 2.057, 2.045, 2.039, 2.015,
#
# reuters_pars
# performed 8 iterations.
# donald, promise, trumps, trail, republican, incoming, priorities, tone, inaugurated,
# 3.398, 3.262, 3.063, 2.999, 2.942, 2.867, 2.856, 2.804, 2.725,
#
# huffpo_pars
# performed 8 iterations.
# donald, swamp, cabinet, promises, presidency, rhetoric, russians, drawn, elect,
# 3.209, 2.781, 2.727, 2.718, 2.582, 2.528, 2.512, 2.504, 2.497,
#
# watimes_pars
# performed 8 iterations.
# trumps, donald, incoming, comments, cabinet, presidents, presidential, billionaire, romney,
# 3.121, 2.707, 2.378, 2.367, 2.322, 2.316, 2.216, 2.182, 2.181,
#
# "military" ===========================
# p = 0.1 ============
# wapo_pars
# performed 52 iterations.
# organizing, shifting, mere, recruit, strategies, relief, discovery, thoroughly, scandals,
# 1.953, 1.920, 1.919, 1.914, 1.909, 1.901, 1.893, 1.877, 1.867,
#
# foxnews_pars
# performed 35 iterations.
# azaria, movement, created, domestic, numerous, maintain, running, raising, fully,
# 1.029, 1.028, 1.025, 1.024, 1.010, 1.008, 1.007, 1.003, 1.002,
#
# cbsnews_pars
# performed 1001 iterations.
# reach, hands, wife, banks, planned, giving, seek, laird, individual,
# 0.433, 0.431, 0.430, 0.430, 0.429, 0.429, 0.428, 0.428, 0.428,
# cnn_pars
# performed 1001 iterations.
# active, warning, figures, heavily, amid, activity, addition, fully, advance,
# 1.339, 1.328, 1.321, 1.309, 1.307, 1.302, 1.300, 1.292, 1.284,
#
# nytimes_pars
# performed 38 iterations.
# map, participants, temporarily, participate, wary, flood, symbolic, engaged, maintained,
# 1.751, 1.741, 1.733, 1.711, 1.710, 1.695, 1.691, 1.685, 1.675,
#
# usatoday_pars
# performed 20 iterations.
# significant, critics, 70, running, response, refugee, hold, phone, helped,
# 0.271, 0.270, 0.269, 0.269, 0.269, 0.269, 0.269, 0.269, 0.269,
#
# breitbart_pars
# performed 40 iterations.
# source, remains, socialist, travel, built, fall, break, claiming, lack,
# 1.072, 1.068, 1.067, 1.066, 1.062, 1.056, 1.055, 1.052, 1.050,
#
# reuters_pars
# performed 49 iterations.
# pointing, favors, latter, warnings, flights, acted, indeed, breaking, marks,
# 2.479, 2.453, 2.355, 2.353, 2.337, 2.293, 2.278, 2.264, 2.235,
#
# huffpo_pars
# performed 63 iterations.
# involves, emphasized, normally, developments, participating, attempting, rescue, institution, holds,
# 2.070, 2.042, 2.041, 2.031, 2.008, 1.969, 1.966, 1.949, 1.932,
#
# watimes_pars
# performed 1001 iterations.
# bar, actual, pointed, focusing, launch, notion, laid, highly, counter,
# 1.743, 1.715, 1.711, 1.711, 1.699, 1.699, 1.687, 1.680, 1.676,
#
# "military" ===========================
# p = 0.5 ============
# wapo_pars
# performed 25 iterations.
# missions, combat, personnel, active, cyber, drones, drone, niger, deployed,
# 2.466, 2.301, 2.279, 2.256, 2.249, 2.247, 2.246, 2.241, 2.235,
#
# foxnews_pars
# performed 23 iterations.
# turkey, opposition, terrorism, ally, threats, turkish, regional, key, qaeda,
# 1.422, 1.401, 1.393, 1.348, 1.344, 1.344, 1.344, 1.342, 1.332,
#
# cbsnews_pars
# performed 15 iterations.
# central, iran, aid, hands, protesters, bank, ordered, remain, turkey,
# 0.451, 0.450, 0.449, 0.449, 0.448, 0.448, 0.447, 0.446, 0.445,
#
# cnn_pars
# performed 22 iterations.
# aircraft, meanwhile, presence, japan, air, strike, pacific, territory, missile,
# 1.780, 1.751, 1.735, 1.735, 1.714, 1.703, 1.701, 1.700, 1.693,
#
# nytimes_pars
# performed 22 iterations.
# drone, civilian, tactics, strikes, counterterrorism, palestinian, confrontation, honduras, aircraft,
# 2.027, 2.010, 1.969, 1.959, 1.930, 1.917, 1.891, 1.878, 1.870,
#
# usatoday_pars
# performed 15 iterations.
# level, germany, due, refugee, key, response, certain, given, 70,
# 0.277, 0.274, 0.273, 0.273, 0.272, 0.272, 0.272, 0.272, 0.272,
#
# breitbart_pars
# performed 24 iterations.
# rebel, islands, militias, chinas, vietnam, regional, aid, taliban, combat,
# 1.286, 1.282, 1.254, 1.251, 1.236, 1.233, 1.226, 1.223, 1.217,
#
# reuters_pars
# performed 24 iterations.
# pilots, deployment, houthis, latter, revenge, confrontation, missile, missiles, personnel,
# 2.454, 2.447, 2.443, 2.393, 2.375, 2.375, 2.353, 2.351, 2.345,
#
# huffpo_pars
# performed 24 iterations.
# rescue, diplomacy, sought, farc, designated, poachers, rebels, imposed, command,
# 2.440, 2.386, 2.373, 2.366, 2.320, 2.311, 2.273, 2.243, 2.193,
#
# watimes_pars
# performed 24 iterations.
# ground, civilian, combat, numerous, guantanamo, fighter, targets, rebels, command,
# 2.029, 2.017, 2.005, 2.003, 1.995, 1.990, 1.960, 1.960, 1.949,
#
# "military" ===========================
# p = 0.9 ============
# wapo_pars
# performed 12 iterations.
# civilian, operations, command, drones, combat, personnel, counterterrorism, pentagon, drone,
# 3.215, 3.060, 3.059, 2.991, 2.947, 2.941, 2.936, 2.931, 2.926,
#
# foxnews_pars
# performed 12 iterations.
# opposition, terrorism, turkey, israeli, civil, assad, settlements, radical, muslim,
# 1.920, 1.915, 1.891, 1.815, 1.781, 1.728, 1.696, 1.677, 1.674,
#
# cbsnews_pars
# performed 10 iterations.
# fighting, rebels, aid, iran, central, civil, west, remain, army,
# 0.500, 0.490, 0.490, 0.487, 0.483, 0.479, 0.474, 0.473, 0.472,
#
# cnn_pars
# performed 12 iterations.
# assad, troops, air, crimea, japan, aircraft, ceasefire, western, pacific,
# 2.340, 2.265, 2.235, 2.170, 2.140, 2.138, 2.116, 2.088, 2.078,
#
# nytimes_pars
# performed 13 iterations.
# operations, drone, counterterrorism, forces, diplomats, philippines, syrian, iranian, civilian,
# 2.345, 2.332, 2.331, 2.290, 2.232, 2.231, 2.221, 2.191, 2.189,
#
# usatoday_pars
# performed 10 iterations.
# level, iraq, germany, record, prosecutors, efforts, due, held, syria,
# 0.291, 0.291, 0.289, 0.288, 0.288, 0.288, 0.284, 0.284, 0.283,
#
# breitbart_pars
# performed 12 iterations.
# sea, forces, troops, pakistan, islands, sudan, fighters, iraqi, rebel,
# 1.694, 1.676, 1.623, 1.621, 1.602, 1.599, 1.589, 1.580, 1.576,
#
# reuters_pars
# performed 13 iterations.
# pilots, training, missiles, houthis, command, personnel, jets, commanders, operation,
# 2.795, 2.787, 2.755, 2.752, 2.687, 2.662, 2.644, 2.624, 2.601,
#
# huffpo_pars
# performed 13 iterations.
# operations, humanitarian, troops, rebels, diplomacy, imposed, kenya, command, korean,
# 2.810, 2.781, 2.672, 2.642, 2.606, 2.555, 2.551, 2.515, 2.501,
#
# watimes_pars
# performed 12 iterations.
# forces, civilian, turkish, force, troops, command, crisis, offensive, presence,
# 2.780, 2.614, 2.581, 2.570, 2.522, 2.396, 2.389, 2.377, 2.332,
#
# "military" ===========================
# p = 0.99 ============
# wapo_pars
# performed 8 iterations.
# operations, civilian, command, drones, combat, pentagon, counterterrorism, troops, personnel,
# 3.341, 3.183, 3.158, 3.049, 3.031, 3.026, 3.023, 3.023, 3.011,
#
# foxnews_pars
# performed 7 iterations.
# opposition, civil, terrorism, turkey, israeli, assad, iran, settlements, radical,
# 1.997, 1.991, 1.979, 1.973, 1.901, 1.826, 1.783, 1.750, 1.738,
#
# cbsnews_pars
# performed 7 iterations.
# fighting, rebels, civil, aid, iran, central, iraqi, west, troops,
# 0.516, 0.504, 0.499, 0.498, 0.494, 0.489, 0.489, 0.488, 0.486,
#
# cnn_pars
# performed 8 iterations.
# assad, troops, air, crimea, ceasefire, japan, regime, western, aircraft,
# 2.454, 2.325, 2.313, 2.233, 2.217, 2.206, 2.175, 2.175, 2.168,
#
# nytimes_pars
# performed 8 iterations.
# forces, operations, drone, counterterrorism, diplomats, syrian, philippines, iranian, weapons,
# 2.440, 2.376, 2.373, 2.341, 2.335, 2.300, 2.261, 2.256, 2.242,
#
# usatoday_pars
# performed 6 iterations.
# iraq, germany, level, record, prosecutors, efforts, due, syria, held,
# 0.294, 0.294, 0.293, 0.293, 0.292, 0.291, 0.289, 0.287, 0.286,
#
# breitbart_pars
# performed 8 iterations.
# sea, forces, troops, south, pakistan, sudan, iraqi, islands, fighters,
# 1.818, 1.744, 1.710, 1.685, 1.677, 1.667, 1.666, 1.660, 1.654,
#
# reuters_pars
# performed 8 iterations.
# training, pilots, command, missiles, houthis, personnel, jets, commanders, operation,
# 2.873, 2.842, 2.839, 2.788, 2.727, 2.712, 2.709, 2.690, 2.640,
#
# huffpo_pars
# performed 8 iterations.
# operations, troops, humanitarian, rebels, diplomacy, imposed, sudan, forces, kenya,
# 2.886, 2.880, 2.708, 2.654, 2.637, 2.630, 2.625, 2.617, 2.594,
#
# watimes_pars
# performed 8 iterations.
# forces, civilian, turkish, force, troops, command, kurdish, crisis, offensive,
# 2.874, 2.734, 2.704, 2.679, 2.588, 2.464, 2.455, 2.439, 2.426,
#
# "clinton" ===========================
# p = 0.1 ============
# wapo_pars
# performed 1001 iterations.
# heated, highlights, attempting, instances, shifting, similarly, ad, discovery, match,
# 2.013, 1.972, 1.949, 1.942, 1.938, 1.910, 1.907, 1.901, 1.893,
#
# foxnews_pars
# performed 33 iterations.
# library, break, clearly, successful, secret, numerous, attempt, hollande, neither,
# 1.058, 1.049, 1.047, 1.029, 1.024, 1.023, 1.020, 1.017, 1.014,
#
# cbsnews_pars
# performed 28 iterations.
# policies, throughout, despite, choice, expressed, calling, toward, suggested, potential,
# 0.478, 0.477, 0.476, 0.475, 0.475, 0.474, 0.474, 0.473, 0.470,
#
# cnn_pars
# performed 46 iterations.
# points, highly, strongly, partisan, none, represents, figures, rare, fully,
# 1.310, 1.284, 1.283, 1.282, 1.279, 1.276, 1.270, 1.269, 1.268,
#
# nytimes_pars
# performed 1001 iterations.
# map, lists, participate, troubles, assumed, chaotic, participants, demonstrated, meanwhile,
# 1.794, 1.791, 1.776, 1.768, 1.759, 1.758, 1.739, 1.737, 1.737,
#
# usatoday_pars
# performed 1001 iterations.
# answer, despite, chance, nothing, politics, moment, trying, run, address,
# 0.294, 0.294, 0.294, 0.294, 0.292, 0.292, 0.292, 0.291, 0.291,
#
# breitbart_pars
# performed 37 iterations.
# pointed, discuss, publicly, child, suggests, soon, maybe, claiming, intended,
# 1.108, 1.096, 1.093, 1.087, 1.086, 1.086, 1.084, 1.084, 1.084,
#
# reuters_pars
# performed 58 iterations.
# pointing, favors, breaking, indeed, warnings, acted, string, demonstrated, occurred,
# 2.558, 2.488, 2.439, 2.418, 2.363, 2.350, 2.331, 2.329, 2.319,
#
# huffpo_pars
# performed 46 iterations.
# nonetheless, badly, ignoring, suit, involves, founders, proved, emphasized, attached,
# 2.057, 2.048, 1.988, 1.987, 1.978, 1.978, 1.973, 1.958, 1.957,
#
# watimes_pars
# performed 43 iterations.
# regularly, double, actual, intent, super, noting, reputation, unusual, troubling,
# 1.797, 1.770, 1.756, 1.744, 1.743, 1.740, 1.735, 1.732, 1.732,
#
# "clinton" ===========================
# p = 0.5 ============
# wapo_pars
# performed 24 iterations.
# hillary, opponent, romney, mitt, ads, dnc, insults, ballot, hacked,
# 2.704, 2.572, 2.538, 2.512, 2.410, 2.390, 2.381, 2.269, 2.251,
#
# foxnews_pars
# performed 20 iterations.
# suggested, candidate, elections, inaugural, race, expected, nominees, nomination, hearings,
# 1.500, 1.482, 1.479, 1.478, 1.471, 1.465, 1.462, 1.456, 1.444,
#
# cbsnews_pars
# performed 17 iterations.
# candidate, nominee, presidency, victory, russia, win, top, republican, incoming,
# 1.219, 1.187, 1.185, 1.159, 1.156, 1.148, 1.140, 1.137, 1.122,
#
# cnn_pars
# performed 23 iterations.
# candidates, defeat, popular, cast, primary, polls, hillary, candidate, emails,
# 1.864, 1.845, 1.753, 1.748, 1.737, 1.736, 1.731, 1.681, 1.679,
#
# nytimes_pars
# performed 23 iterations.
# hillary, trail, romney, speeches, debates, portman, hacked, contest, contrast,
# 2.343, 2.269, 2.263, 2.208, 2.193, 2.169, 2.128, 2.122, 2.108,
#
# usatoday_pars
# performed 1001 iterations.
# candidate, cabinet, supporters, nominees, hillary, putin, nominee, russia, democrats,
# 0.710, 0.707, 0.706, 0.697, 0.692, 0.692, 0.687, 0.682, 0.677,
#
# breitbart_pars
# performed 24 iterations.
# clintons, emails, foundation, democratic, investigation, answer, questions, hillary, server,
# 2.215, 2.133, 2.068, 2.056, 2.039, 1.998, 1.919, 1.882, 1.870,
#
# reuters_pars
# performed 24 iterations.
# hillary, opponent, controversy, demonstrated, democrat, affair, romney, divisive, beat,
# 3.363, 3.350, 3.175, 3.167, 3.156, 3.000, 2.852, 2.816, 2.760,
#
# huffpo_pars
# performed 24 iterations.
# hillary, popular, preferred, accusations, candidate, opponent, russians, kremlin, nonetheless,
# 2.583, 2.571, 2.545, 2.483, 2.472, 2.438, 2.396, 2.395, 2.389,
#
# watimes_pars
# performed 24 iterations.
# hillary, super, clintons, romney, candidate, mitt, sanders, popular, tuesdays,
# 2.204, 2.172, 2.126, 2.078, 2.070, 2.027, 2.018, 2.011, 1.989,
#
# "clinton" ===========================
# p = 0.9 ============
# wapo_pars
# performed 12 iterations.
# hillary, romney, opponent, mitt, candidate, podesta, ballot, dnc, bernie,
# 3.627, 3.470, 3.398, 3.108, 3.031, 3.011, 3.000, 2.949, 2.889,
#
# foxnews_pars
# performed 12 iterations.
# hillary, vote, republican, presidential, gop, confirmation, bill, electoral, nominee,
# 2.129, 2.037, 2.010, 2.008, 1.995, 1.987, 1.966, 1.954, 1.945,
#
# cbsnews_pars
# performed 10 iterations.
# hillary, presidential, candidate, republican, campaign, election, transition, administration, trumps,
# 2.402, 2.277, 2.215, 2.179, 2.162, 1.997, 1.977, 1.973, 1.962,
#
# cnn_pars
# performed 13 iterations.
# hillary, popular, candidate, presidential, electoral, nominee, defeat, candidates, votes,
# 2.541, 2.456, 2.392, 2.351, 2.262, 2.175, 2.168, 2.163, 2.152,
#
# nytimes_pars
# performed 12 iterations.
# hillary, campaign, candidate, presidential, opponent, cast, emails, votes, ballots,
# 3.208, 2.979, 2.909, 2.826, 2.803, 2.787, 2.766, 2.748, 2.695,
#
# usatoday_pars
# performed 9 iterations.
# presidential, presidency, hillary, inauguration, order, cabinet, russia, candidate, bush,
# 1.551, 1.551, 1.492, 1.344, 1.292, 1.286, 1.276, 1.276, 1.268,
#
# breitbart_pars
# performed 12 iterations.
# hillary, clintons, emails, investigation, foundation, nominee, democratic, email, secretary,
# 3.183, 3.181, 2.974, 2.960, 2.873, 2.649, 2.588, 2.417, 2.375,
#
# reuters_pars
# performed 14 iterations.
# hillary, democrat, opponent, controversy, affair, romney, presidential, candidate, nomination,
# 3.964, 3.749, 3.489, 3.401, 3.392, 3.240, 3.216, 3.154, 3.112,
#
# huffpo_pars
# performed 12 iterations.
# hillary, popular, candidate, sanders, dnc, opponent, preferred, russians, bernie,
# 3.517, 3.462, 3.443, 3.152, 2.995, 2.936, 2.909, 2.875, 2.848,
#
# watimes_pars
# performed 12 iterations.
# hillary, clintons, romney, candidate, mitt, popular, nominee, cast, sanders,
# 3.009, 2.826, 2.786, 2.759, 2.729, 2.568, 2.503, 2.455, 2.450,
#
# "clinton" ===========================
# p = 0.99 ============
# wapo_pars
# performed 8 iterations.
# hillary, romney, opponent, mitt, candidate, podesta, ballot, dnc, bernie,
# 3.761, 3.562, 3.505, 3.217, 3.166, 3.086, 3.069, 3.060, 2.964,
#
# foxnews_pars
# performed 8 iterations.
# hillary, vote, republican, presidential, gop, bill, confirmation, democratic, electoral,
# 2.217, 2.142, 2.128, 2.077, 2.071, 2.068, 2.044, 2.026, 2.022,
#
# cbsnews_pars
# performed 7 iterations.
# hillary, presidential, election, campaign, candidate, republican, trumps, administration, obama,
# 2.649, 2.461, 2.427, 2.426, 2.369, 2.322, 2.199, 2.157, 2.130,
#
# cnn_pars
# performed 8 iterations.
# hillary, popular, candidate, presidential, electoral, nominee, votes, vote, win,
# 2.630, 2.546, 2.521, 2.442, 2.364, 2.241, 2.220, 2.220, 2.209,
#
# nytimes_pars
# performed 8 iterations.
# hillary, campaign, candidate, presidential, opponent, cast, votes, emails, ballots,
# 3.370, 3.109, 3.062, 2.919, 2.910, 2.902, 2.891, 2.837, 2.739,
#
# usatoday_pars
# performed 7 iterations.
# presidential, presidency, hillary, inauguration, campaign, order, bush, cabinet, russia,
# 1.727, 1.716, 1.665, 1.587, 1.530, 1.413, 1.401, 1.399, 1.376,
#
# breitbart_pars
# performed 8 iterations.
# hillary, emails, clintons, investigation, foundation, nominee, democratic, email, secretary,
# 3.304, 3.273, 3.091, 3.064, 3.002, 2.719, 2.713, 2.594, 2.511,
#
# reuters_pars
# performed 8 iterations.
# hillary, democrat, opponent, controversy, romney, affair, presidential, candidate, nomination,
# 4.051, 3.781, 3.491, 3.425, 3.415, 3.330, 3.292, 3.208, 3.090,
#
# huffpo_pars
# performed 8 iterations.
# hillary, popular, candidate, sanders, dnc, opponent, bernie, emails, preferred,
# 3.631, 3.580, 3.575, 3.241, 3.051, 2.977, 2.975, 2.970, 2.957,
#
# watimes_pars
# performed 8 iterations.
# hillary, clintons, romney, candidate, mitt, popular, nominee, presidential, cast,
# 3.112, 2.910, 2.871, 2.842, 2.818, 2.667, 2.586, 2.562, 2.505,
#
# "war" ===========================
# p = 0.1 ============
# wapo_pars
# performed 1001 iterations.
# highlights, heated, mere, organizing, thoroughly, shifting, cruel, protesting, echo,
# 1.956, 1.947, 1.943, 1.925, 1.923, 1.914, 1.885, 1.883, 1.875,
#
# foxnews_pars
# performed 53 iterations.
# fears, massive, movement, domestic, class, fully, worst, possibility, success,
# 1.015, 1.014, 1.009, 1.006, 0.999, 0.999, 0.998, 0.996, 0.994,
#
# cbsnews_pars
# performed 33 iterations.
# reach, hands, giving, wife, remains, banks, played, damage, planned,
# 0.430, 0.430, 0.428, 0.428, 0.427, 0.426, 0.426, 0.426, 0.426,
#
# cnn_pars
# performed 171 iterations.
# divided, figures, active, warning, onto, amid, present, stage, promote,
# 1.289, 1.281, 1.277, 1.271, 1.260, 1.259, 1.258, 1.254, 1.250,
#
# nytimes_pars
# performed 65 iterations.
# wary, map, symbolic, flood, notable, breaking, hunt, acceptance, participate,
# 1.739, 1.727, 1.717, 1.703, 1.697, 1.694, 1.694, 1.692, 1.692,
#
# usatoday_pars
# performed 21 iterations.
# significant, class, critics, response, 70, helped, reason, refugee, sometimes,
# 0.271, 0.271, 0.270, 0.270, 0.269, 0.269, 0.269, 0.269, 0.268,
#
# breitbart_pars
# performed 34 iterations.
# strike, appears, fall, believed, started, goal, break, abbas, coup,
# 1.059, 1.057, 1.054, 1.054, 1.048, 1.048, 1.043, 1.043, 1.041,
#
# reuters_pars
# performed 40 iterations.
# pointing, favors, latter, breaking, indeed, warnings, acted, occurred, proved,
# 2.415, 2.355, 2.323, 2.300, 2.271, 2.258, 2.253, 2.248, 2.237,
#
# huffpo_pars
# performed 42 iterations.
# confronted, begun, developments, emphasized, involves, attempting, attached, ignoring, pointing,
# 2.008, 1.998, 1.971, 1.970, 1.963, 1.950, 1.944, 1.930, 1.924,
#
# watimes_pars
# performed 47 iterations.
# bar, 1970s, laid, pointed, flag, actual, focusing, launch, elite,
# 1.705, 1.693, 1.691, 1.690, 1.684, 1.684, 1.676, 1.668, 1.664,
#
# "war" ===========================
# p = 0.5 ============
# wapo_pars
# performed 22 iterations.
# revolutionary, ii, vietnam, brutal, zone, duterte, ending, battle, dictator,
# 2.566, 2.409, 2.375, 2.319, 2.231, 2.182, 2.176, 2.169, 2.165,
#
# foxnews_pars
# performed 19 iterations.
# assad, ii, refugees, terrorists, turkey, terror, europe, territory, citizens,
# 1.534, 1.469, 1.443, 1.410, 1.409, 1.376, 1.369, 1.363, 1.350,
#
# cbsnews_pars
# performed 15 iterations.
# iran, remains, israel, religious, inside, hands, aid, global, programs,
# 0.444, 0.440, 0.440, 0.439, 0.437, 0.437, 0.436, 0.434, 0.434,
#
# cnn_pars
# performed 20 iterations.
# ii, pakistan, largest, powerful, end, battle, arms, cuba, continent,
# 1.685, 1.682, 1.681, 1.653, 1.650, 1.626, 1.601, 1.587, 1.579,
#
# nytimes_pars
# performed 23 iterations.
# ii, chaos, suffered, hitler, remains, indonesia, revolution, humanity, cold,
# 2.260, 2.225, 2.223, 2.113, 2.103, 2.087, 2.078, 2.058, 2.052,
#
# usatoday_pars
# performed 12 iterations.
# role, hundreds, town, calls, class, economy, response, sent, continue,
# 0.288, 0.286, 0.283, 0.280, 0.280, 0.278, 0.278, 0.277, 0.277,
#
# breitbart_pars
# performed 22 iterations.
# ii, generational, ukraine, conflict, bashar, allies, regime, crisis, rebels,
# 1.490, 1.422, 1.412, 1.373, 1.358, 1.347, 1.341, 1.335, 1.314,
#
# reuters_pars
# performed 25 iterations.
# rebellion, 1980s, escalation, defending, brutal, mistake, uprising, bashar, ending,
# 2.781, 2.571, 2.473, 2.431, 2.428, 2.371, 2.354, 2.341, 2.341,
#
# huffpo_pars
# performed 26 iterations.
# 1980s, brutal, sweden, invasion, korean, poachers, ii, fidel, talks,
# 2.532, 2.414, 2.411, 2.404, 2.365, 2.349, 2.333, 2.317, 2.289,
#
# watimes_pars
# performed 21 iterations.
# fought, ii, revolution, cold, heritage, wars, afghanistan, medal, terror,
# 2.611, 2.421, 2.415, 2.342, 2.270, 2.268, 2.266, 2.234, 2.231,
#
# "war" ===========================
# p = 0.9 ============
# wapo_pars
# performed 12 iterations.
# ii, vietnam, cold, revolutionary, revolution, soviet, brutal, fighting, afghanistan,
# 3.223, 3.001, 2.987, 2.927, 2.850, 2.836, 2.821, 2.666, 2.654,
#
# foxnews_pars
# performed 12 iterations.
# assad, fighting, syria, ii, terror, refugees, rebels, iran, country,
# 2.236, 2.152, 2.139, 2.019, 1.977, 1.961, 1.910, 1.888, 1.883,
#
# cbsnews_pars
# performed 10 iterations.
# fighting, iran, rebels, killing, special, rights, taken, aid, religious,
# 0.481, 0.478, 0.475, 0.473, 0.470, 0.469, 0.468, 0.468, 0.465,
#
# cnn_pars
# performed 12 iterations.
# ii, end, cold, soviet, pakistan, conflict, afghanistan, powerful, europe,
# 2.357, 2.223, 2.198, 2.055, 2.005, 1.984, 1.981, 1.947, 1.921,
#
# nytimes_pars
# performed 13 iterations.
# ii, vietnam, cold, wars, soviet, revolution, hitler, ukraine, regime,
# 2.893, 2.846, 2.713, 2.612, 2.559, 2.537, 2.506, 2.499, 2.441,
#
# usatoday_pars
# performed 10 iterations.
# hundreds, role, iraq, calls, 24, record, town, drugs, syria,
# 0.320, 0.309, 0.306, 0.305, 0.305, 0.305, 0.302, 0.302, 0.301,
#
# breitbart_pars
# performed 13 iterations.
# generational, world, russia, ii, iran, syria, crisis, allies, conflict,
# 1.932, 1.932, 1.917, 1.808, 1.770, 1.741, 1.726, 1.696, 1.684,
#
# reuters_pars
# performed 12 iterations.
# rebellion, civil, 1980s, wars, bashar, escalation, conflict, brutal, uprising,
# 2.958, 2.927, 2.899, 2.845, 2.815, 2.750, 2.714, 2.682, 2.598,
#
# huffpo_pars
# performed 13 iterations.
# ii, vietnam, wars, invasion, cold, afghanistan, iraq, yemen, syria,
# 3.189, 3.119, 3.049, 2.972, 2.957, 2.905, 2.854, 2.839, 2.823,
#
# watimes_pars
# performed 12 iterations.
# ii, world, cold, fought, afghanistan, fighting, heritage, terror, wars,
# 3.446, 3.342, 3.222, 3.046, 2.887, 2.770, 2.758, 2.732, 2.718,
#
# "war" ===========================
# p = 0.99 ============
# wapo_pars
# performed 8 iterations.
# ii, vietnam, cold, revolution, revolutionary, soviet, fighting, brutal, afghanistan,
# 3.324, 3.127, 3.022, 3.015, 2.983, 2.934, 2.887, 2.796, 2.749,
#
# foxnews_pars
# performed 7 iterations.
# assad, fighting, syria, ii, terror, rebels, iran, refugees, syrian,
# 2.365, 2.350, 2.220, 2.102, 2.062, 2.050, 2.044, 2.033, 2.004,
#
# cbsnews_pars
# performed 6 iterations.
# fighting, rights, rebels, killing, iran, special, wounded, taken, aid,
# 0.494, 0.492, 0.489, 0.488, 0.483, 0.478, 0.477, 0.475, 0.473,
#
# cnn_pars
# performed 7 iterations.
# ii, end, cold, soviet, pakistan, conflict, afghanistan, europe, powerful,
# 2.449, 2.313, 2.284, 2.098, 2.084, 2.048, 2.046, 2.014, 2.008,
#
# nytimes_pars
# performed 8 iterations.
# ii, vietnam, cold, wars, soviet, revolution, ukraine, hitler, regime,
# 3.029, 2.947, 2.847, 2.718, 2.615, 2.608, 2.570, 2.560, 2.488,
#
# usatoday_pars
# performed 6 iterations.
# hundreds, role, iraq, 24, world, record, calls, west, town,
# 0.326, 0.316, 0.314, 0.313, 0.311, 0.311, 0.310, 0.309, 0.308,
#
# breitbart_pars
# performed 8 iterations.
# generational, world, russia, ii, syria, iran, crisis, allies, japan,
# 2.039, 2.022, 1.970, 1.878, 1.872, 1.792, 1.772, 1.759, 1.731,
#
# reuters_pars
# performed 8 iterations.
# rebellion, civil, wars, 1980s, bashar, escalation, conflict, brutal, uprising,
# 3.087, 2.979, 2.939, 2.905, 2.840, 2.834, 2.744, 2.717, 2.668,
#
# huffpo_pars
# performed 8 iterations.
# ii, vietnam, wars, invasion, cold, afghanistan, iraq, syria, yemen,
# 3.299, 3.228, 3.123, 3.087, 3.076, 3.063, 2.989, 2.987, 2.855,
#
# watimes_pars
# performed 7 iterations.
# ii, world, cold, fought, afghanistan, fighting, terror, heritage, troops,
# 3.622, 3.459, 3.281, 3.141, 2.972, 2.818, 2.818, 2.808, 2.783,

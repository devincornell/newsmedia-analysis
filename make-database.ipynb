# %%
import semanticanalysis as sa
from datetime import datetime
from articles import *

sources = {
    'breitbart': 'Data/scraped_articles_breitbart.json',
    'cbsnews': 'Data/scraped_articles_cbsnews.json',
    'cnn': 'Data/scraped_articles_cnn.json',
    'foxnews': 'Data/scraped_articles_foxnews.json',
    'nytimes': 'Data/scraped_articles_nytimes.json',
    'wapo': 'Data/scraped_articles_washingtonpost.json',
    'huffpo': 'Data/scraped_articles_huffingtonpost.json',
    'reuters': 'Data/scraped_articles_reuters.json',
    'usatoday': 'Data/scraped_articles_usatoday.json',
    'watimes': 'Data/scraped_articles_washingtontimes.json',
    }

# %%
import json
articles = Articles('articles4.db')
for srcname, fname in sources.items():
    with open(fname,encoding='utf-8', errors='surrogateescape') as f:
        dat = json.load(f)
    for url, dat in dat.items():
        yr = int(str(dat['metadata']['timestamp'])[0:4])
        mo = int(str(dat['metadata']['timestamp'])[4:6])
        day = int(str(dat['metadata']['timestamp'])[6:8])
        hr = int(str(dat['metadata']['timestamp'])[8:10])
        dt = datetime(year=yr, month=mo, day=day, hour=hr)
        text = dat['story_content'].encode('utf-8').decode()
        
        articles.add({
            'source':dat['metadata']['source'],
            'date': dt.timestamp(),
            'datestr': dt.strftime("%Y-%m-%d %H"),
            'url': url,
            'meta': dat['metadata'],
            'text': text,
            'headline': dat['headline'],
        })

# %%
articles.getdf(limit=5)
# Out:
#    id         source        date        datestr  \
# 0   1  breitbart.com  1482393600  2016-12-22 00
# 1   2  breitbart.com  1482631200  2016-12-24 18
# 2   3  breitbart.com  1481871600  2016-12-15 23
# 3   4  breitbart.com  1478167200  2016-11-03 03
# 4   5  breitbart.com  1481778000  2016-12-14 21
#
#                                                  url  \
# 0  http://www.breitbart.com/california/2016/12/21...
# 1  http://www.breitbart.com/national-security/201...
# 2  http://www.breitbart.com/news/trump-picks-his-...
# 3  http://www.breitbart.com/big-government/2016/1...
# 4  http://www.breitbart.com/radio/2016/12/14/film...
#
#                                                 meta  \
# 0  {'IngroupVirtue': 2, 'AuthorityVice': 2, 'mft_...
# 1  {'IngroupVirtue': 2, 'AuthorityVice': 0, 'mft_...
# 2  {'IngroupVirtue': 5, 'AuthorityVice': 1, 'mft_...
# 3  {'IngroupVirtue': 3, 'AuthorityVice': 1, 'mft_...
# 4  {'IngroupVirtue': 5, 'AuthorityVice': 0, 'mft_...
#
#                                                 text  \
# 0  Much ink has been spilled, and much bandwidth ...
# 1  The forces of evil aren't taking Christmas off...
# 2  NEW YORK (AP) — Edging closer to completing hi...
# 3  NEW YORK CITY, New York — A pair of reports ou...
# 4  On Wednesday's Breitbart News Daily, documenta...
#
#                                             headline
# 0  ‘Legacy’: 10 Ways Barack Obama Broke the Ameri...
# 1  7 Terror Attacks and Plots Foiled This Christm...
# 2  Trump picks his Interior chief, a supporter of...
# 3  'Validly Predicated Investigation': Reports Pr...
# 4  Filmmaker Ami Horowitz Beaten in Swedish No-Go...
